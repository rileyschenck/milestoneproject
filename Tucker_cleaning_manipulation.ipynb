# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      -------------------------------------  245.8/250.0 kB 5.0 MB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 2.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data=pd.read_csv('Tucker_transcripts_2.5.23.tsv',sep='\t').drop(columns = ['Unnamed: 0'])

# %%
data
# Out:
#                                                    url  \
# 0    https://www.foxnews.com/opinion/tucker-carlson...
# 1    https://www.foxnews.com/opinion/tucker-carlson...
# 2    https://www.foxnews.com/opinion/tucker-carlson...
# 3    https://www.foxnews.com/opinion/tucker-carlson...
# 4    https://www.foxnews.com/opinion/tucker-carlson...
# ..                                                 ...
# 316  https://www.foxnews.com/opinion/tucker-carlson...
# 317  https://www.foxnews.com/opinion/tucker-carlson...
# 318  https://www.foxnews.com/opinion/tucker-carlson...
# 319  https://www.foxnews.com/opinion/tucker-carlson...
# 320  https://www.foxnews.com/opinion/tucker-carlson...
#
#                          timestamp  \
# 0      February 3, 2023 9:59pm EST
# 1     February 2, 2023 10:32pm EST
# 2     January 31, 2023 10:03pm EST
# 3      January 30, 2023 9:49pm EST
# 4      January 27, 2023 9:52pm EST
# ..                             ...
# 316        July 1, 2021 1:12am EDT
# ...

# %%
pew= pd.read_excel('Pew Issue Polling 2022.xlsx')

# %%
pew
# Out:
#                                    issue  Mar. 1-31, 2022 Total   Repub   Dem  \
# 0                               Abortion                    0.43   0.40  0.46
# 1                              Education                    0.59   0.53  0.66
# 2                            Immigration                    0.49   0.68  0.34
# 3                          Violent crime                    0.56   0.67  0.47
# 4                            Health care                    0.60   0.44  0.74
# 5                             Gun policy                    0.54   0.55  0.54
# 6                          Energy policy                    0.59   0.62  0.58
# 7                                Economy                    0.78   0.90  0.68
# 8       Issues around race and ethnicity                    0.35   0.14  0.54
# 9             Supreme Court appointments                    0.56   0.55  0.59
# 10  Size and scope of federal government                    0.43   0.62  0.26
# ...

# %%
import re

# %%
data2=data #.copy()
#data2['url'][2] = None

# %%
for pewrow in pew['primary dict']:
    print(pewrow.split(','))
# Out:
# ['abortion', 'pro choice', '+O1+B2:N2+A2:N2']
# ['education', 'schools', 'teachers']
# ['immigration', 'migration', 'immigrants', ' migrants', 'assylum', 'southern border']
# ['crime']
# ['health care']
# ['guns', 'mass shooting', 'mass shootings', ' second ammendment', 'assault weapons']
# ['energy policy', 'green new deal', ' renewable energy', 'renewables', 'wind', ' solar', 'electrification', 'fossil fuels']
# ['economy', 'inflation', 'jobs', 'wages', 'unemployment', ' salaries']
# ['black lives matter', 'blm', 'police misconduct', 'social justice']
# ['supreme court', ' justices']
# ['small government', 'big government', 'spending cuts']
# ['climate change', 'global warming']
# ['election fraud', 'voter supression', 'fake electors', 'january 6', 'january 6th']
# ['foreign policy', 'ukraine', 'russia', 'china', 'nato', 'alliance', 'putin', 'xi', 'jinping']
# ['coronavirus', 'covid', 'pandemic']
# ['avoidingNaNvalues']
# ['investigation', 'investigations']
# ...

# %%
# make all text in transcript lower case
for count, row in enumerate(data2['text']):
    data2['text'][count]= row.lower()

# %%
df = data2[:5]

# %%
for row in pew['issue']:
    df[row] = None

df
# Out:
# C:\Users\rache\AppData\Local\Temp\ipykernel_9916\2802921870.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[row] = None
# C:\Users\rache\AppData\Local\Temp\ipykernel_9916\2802921870.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[row] = None
# C:\Users\rache\AppData\Local\Temp\ipykernel_9916\2802921870.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
for count, row in enumerate(df['text']): 
    print(count)
    match = re.findall(r'\btucker\b',row)
    print(match)
    df['Abortion'][count] = match
# Out:
# 0
# ['tucker', 'tucker']
# 1
# ['tucker', 'tucker']
# 2
# ['tucker', 'tucker', 'tucker']
# 3
# ['tucker', 'tucker']
# 4
# ['tucker', 'tucker']
# C:\Users\rache\AppData\Local\Temp\ipykernel_9916\2236765341.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Abortion'][count] = match

# %%
df
# Out:
#                                                  url  \
# 0  https://www.foxnews.com/opinion/tucker-carlson...
# 1  https://www.foxnews.com/opinion/tucker-carlson...
# 2  https://www.foxnews.com/opinion/tucker-carlson...
# 3  https://www.foxnews.com/opinion/tucker-carlson...
# 4  https://www.foxnews.com/opinion/tucker-carlson...
#
#                        timestamp  \
# 0    February 3, 2023 9:59pm EST
# 1   February 2, 2023 10:32pm EST
# 2   January 31, 2023 10:03pm EST
# 3    January 30, 2023 9:49pm EST
# 4    January 27, 2023 9:52pm EST
#
#                                                title  \
# 0  TUCKER CARLSON: Biden administration's stance ...
# 1  TUCKER CARLSON: Hunter Biden versus laptop rep...
# 2  TUCKER CARLSON: Will we see a whole lot more o...
# 3  TUCKER CARLSON: Why we're paranoid about the A...
# 4  TUCKER CARLSON: Another attempt by leaders of ...
#
#                                                 text  \
# 0   fox news host tucker carlson takes on the bid...
# ...
