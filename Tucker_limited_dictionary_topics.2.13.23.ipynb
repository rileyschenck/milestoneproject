# %% [markdown]
# ## Tucker Carlson Limited Dictionary Topic Analysis

# %%
import pandas as pd

# %%
#pip install openpyxl

# %%
data=pd.read_csv('Tucker_transcripts_2.10.23.tsv',sep='\t').drop(columns = ['Unnamed: 0'])

# %%
data.iloc[0,3]
# Out:
# "WARNING: Graphic footage—Fox News host Tucker Carlson voices his concerns over rising crime on 'Tucker Carlson Tonight.' It used to be before liberals embraced authoritarianism that they would talk a lot about rights. You couldn’t debate whether those rights or not.But if you're talking about rights, you at some point want to identify the most basic human right of all. What is that? Well, of course, it's the. That's the essential right upon which all other rights depend. If you can't defend yourself, you can't defend your family and your property, you don't have any rights at all. You're a slave by definition. So, you may be wondering in this moment of creeping authoritarianism, how is the right to self-defense doing in our country? We could give some kind of long lecture, but instead, how about some examples? Consider two shootings that took place at gas stations in the past year in the United States. The first shooting occurred around 2 p.m. on October 6 in the state of Missouri. A 23-year-old felon called Ja'Von Taylor, who had a long criminal record of convictions for armed robbery, for example, began threatening a female clerk, apparently because the gas station didn't carry the kind of cigars that he wanted.  That's when an off-duty fireman called Anthony Santi, who was inside, decided to step in. He told Ja'Von Taylor to leave the store. Well, in response to that, Taylor began threatening him and then ran toward his SUV outside. Santi followed him outside because he suspected that Ja'Von Taylor would retrieve a gun from the car and that's exactly what he did. Javon Taylor pulled an illegal handgun with an extended magazine from his SUV.  Santi, not wanting to get shot, put Taylor in a headlock and that's when Ja'Von Taylor handed the gun to his girlfriend and his girlfriend shot the unarmed fireman in the back, killing him. It was an execution. It's not a close call. The footage is online. We're not going to show it to you because it's awful. But if you have any doubt, you can watch it. So, there's no debate about what happened here. And yet the local social justice D.A., Jean Peters Baker, refused to press charges against the person who killed the firefighter. Now, why? Well, there may have been a political component and we know that because online BLM activists immediately celebrated the killing on racial grounds. Ja'Von Taylor is Black, Anthony Santi was White. That was enough for them. They're glad he's dead. Now consider the second gas station shooting. This one happened just before midnight, less than a month ago in Austin, Texas. An armed man with a long criminal record called Marquis Demps walked into a Shell station and became violent. Here's a report from the local Fox station describing what happened next.  Demps, waving a knife at the workers, so Naz grabbed a gun telling him to leave. Inst So, a guy with a criminal record and a knife in his hand starts trashing your store and then runs outside to his car. You see, Naz told police later that he shot Marquis Demps because he feared for his life. He thought the guy was going to get a gun and come back and kill him. And that's a reasonable fear, of course. The Anthony Santi murder demonstrates that it is, But in this case, the D.A., a Soros-funded anti-police political activist called Jose Garza, is pressing charges against the clerk. He wants you to see Naz – a man who's widely respected in his community and who actually contributes to our society, as you just heard – he's trying to send that man to prison for the rest of his life.  So, put these two cases together, consider them in tandem. What's the message? Well, the message is if a violent felon starts terrorizing people in your store, ripping your store apart on which you rely for your livelihood, you can't do anything. If he goes back to his car to get a gun, you have to let it happen. So, get shot or go to jail for the rest of your life. Those are your choices, which of course, are not really choices a ...

# %%
# Load the regular expression library
import re
# Remove punctuation
data['text_processed'] = \
data['text'].map(lambda x: re.sub('[,\.!?]', '', x))
# Convert the titles to lowercase
data['text_processed'] = \
data['text_processed'].map(lambda x: x.lower())
# Print out the first rows of papers
data['text_processed'].head()
# Out:
# 0    warning: graphic footage—fox news host tucker ...
# 1     fox news host tucker carlson reacts to presid...
# 2    fox news host tucker carlson breaks down the t...
# 3    fox news host tucker carlson calls out the bid...
# 4     fox news host tucker carlson takes on the bid...
# Name: text_processed, dtype: object

# %%
data
data.iloc[0,4]
# Out:
# "warning: graphic footage—fox news host tucker carlson voices his concerns over rising crime on 'tucker carlson tonight' it used to be before liberals embraced authoritarianism that they would talk a lot about rights you couldn’t debate whether those rights or notbut if you're talking about rights you at some point want to identify the most basic human right of all what is that well of course it's the that's the essential right upon which all other rights depend if you can't defend yourself you can't defend your family and your property you don't have any rights at all you're a slave by definition so you may be wondering in this moment of creeping authoritarianism how is the right to self-defense doing in our country we could give some kind of long lecture but instead how about some examples consider two shootings that took place at gas stations in the past year in the united states the first shooting occurred around 2 pm on october 6 in the state of missouri a 23-year-old felon called ja'von taylor who had a long criminal record of convictions for armed robbery for example began threatening a female clerk apparently because the gas station didn't carry the kind of cigars that he wanted  that's when an off-duty fireman called anthony santi who was inside decided to step in he told ja'von taylor to leave the store well in response to that taylor began threatening him and then ran toward his suv outside santi followed him outside because he suspected that ja'von taylor would retrieve a gun from the car and that's exactly what he did javon taylor pulled an illegal handgun with an extended magazine from his suv  santi not wanting to get shot put taylor in a headlock and that's when ja'von taylor handed the gun to his girlfriend and his girlfriend shot the unarmed fireman in the back killing him it was an execution it's not a close call the footage is online we're not going to show it to you because it's awful but if you have any doubt you can watch it so there's no debate about what happened here and yet the local social justice da jean peters baker refused to press charges against the person who killed the firefighter now why well there may have been a political component and we know that because online blm activists immediately celebrated the killing on racial grounds ja'von taylor is black anthony santi was white that was enough for them they're glad he's dead now consider the second gas station shooting this one happened just before midnight less than a month ago in austin texas an armed man with a long criminal record called marquis demps walked into a shell station and became violent here's a report from the local fox station describing what happened next  demps waving a knife at the workers so naz grabbed a gun telling him to leave inst so a guy with a criminal record and a knife in his hand starts trashing your store and then runs outside to his car you see naz told police later that he shot marquis demps because he feared for his life he thought the guy was going to get a gun and come back and kill him and that's a reasonable fear of course the anthony santi murder demonstrates that it is but in this case the da a soros-funded anti-police political activist called jose garza is pressing charges against the clerk he wants you to see naz – a man who's widely respected in his community and who actually contributes to our society as you just heard – he's trying to send that man to prison for the rest of his life  so put these two cases together consider them in tandem what's the message well the message is if a violent felon starts terrorizing people in your store ripping your store apart on which you rely for your livelihood you can't do anything if he goes back to his car to get a gun you have to let it happen so get shot or go to jail for the rest of your life those are your choices which of course are not really choices at all and these are not isolated cases that we cherry pick to make some polemical point it's happening ...

# %%
pew= pd.read_excel('Pew Issue Polling 2022.xlsx')

# %%
pew
# Out:
#                                    issue  Mar. 1-31, 2022 Total   Repub   Dem  \
# 0                               Abortion                    0.43   0.40  0.46
# 1                              Education                    0.59   0.53  0.66
# 2                            Immigration                    0.49   0.68  0.34
# 3                          Violent crime                    0.56   0.67  0.47
# 4                            Health care                    0.60   0.44  0.74
# 5                             Gun policy                    0.54   0.55  0.54
# 6                          Energy policy                    0.59   0.62  0.58
# 7                                Economy                    0.78   0.90  0.68
# 8       Issues around race and ethnicity                    0.35   0.14  0.54
# 9             Supreme Court appointments                    0.56   0.55  0.59
# 10  Size and scope of federal government                    0.43   0.62  0.26
# 11                        Climate change                    0.40   0.14  0.64
# 12                       Voting policies                    0.61   0.58  0.66
# 13                        Foreign policy                    0.59   0.67  0.53
# 14              The coronavirus outbreak                    0.33   0.19  0.46
# 15    Future of Democracy in the country                     NaN    NaN   NaN
# 16             Investigations into Trump                     NaN    NaN   NaN
# 17             Investigations into Biden                     NaN    NaN   NaN
#
#      Aug. 1-14, 2022 Total  Repub.1  Dem.1  Oct. 10-16, 2022 Total  Repub.2  \
# 0                     0.56     0.41   0.71                    0.56     0.39
# 1                     0.58     0.52   0.64                    0.64     0.60
# 2                     0.48     0.66   0.31                    0.54     0.76
# 3                     0.60     0.69   0.52                    0.61     0.74
# 4                     0.60     0.43   0.77                    0.63     0.42
# 5                     0.62     0.52   0.71                    0.57     0.56
# 6                     0.53     0.51   0.56                    0.61     0.63
# 7                     0.77     0.90   0.67                    0.79     0.92
# 8                     0.35     0.15   0.54                    0.34     0.13
# 9                     0.58     0.48   0.69                    0.55     0.52
# 10                    0.42     0.60   0.24                    0.41     0.60
# 11                    0.40     0.13   0.66                    0.38     0.09
# 12                    0.59     0.56   0.64                    0.58     0.57
# 13                    0.45     0.54   0.37                    0.54     0.62
# 14                    0.28     0.13   0.41                    0.23     0.12
# 15                     NaN      NaN    NaN                    0.70     0.70
# 16                     NaN      NaN    NaN                    0.30     0.07
# 17                     NaN      NaN    NaN                    0.29     0.55
#
#     Dem.2  Shift in importance March - OctoberTotal  Repub.3  Dem.3  \
# 0    0.75                                      0.13    -0.01   0.29
# 1    0.66                                      0.05     0.07   0.00
# 2    0.36                                      0.05     0.08   0.02
# 3    0.45                                      0.05     0.07  -0.02
# 4    0.79                                      0.03    -0.02   0.05
# 5    0.62                                      0.03     0.01   0.08
# 6    0.63                                      0.02     0.01   0.05
# 7    0.65                                      0.01     0.02  -0.03
# 8    0.52                                     -0.01    -0.01  -0.02
# 9    0.69                                     -0.01    -0.03   0.10
# 10   0.26                                     -0.02    -0.02   0.00
# 11   0.68                                     -0.02    -0.05   0.04
# 12   0.64                                     -0.03    -0.01  -0.02
# 13   0.49                                     -0.05    -0.05  -0.04
# 14   0.32                                     -0.10    -0.07  -0.14
# 15   0.80                                       NaN      NaN    NaN
# 16   0.56                                       NaN      NaN    NaN
# 17   0.07                                       NaN      NaN    NaN
#
#                                          primary dict  \
# 0   abortion,pro choice,pro-choice,pro life,pro-li...
# 1           education,schools,school,teachers,teacher
# 2   immigration,migration,immigrants, migrants,ass...
# 3                                               crime
# 4                                         health care
# 5   guns,mass shooting,mass shootings, second amme...
# 6   energy policy,green new deal, renewable energy...
# 7   economy,inflation,jobs,wages,unemployment, sal...
# 8   black lives matter,blm,police misconduct,socia...
# 9                             supreme court, justices
# 10      small government,big government,spending cuts
# 11                      climate change,global warming
# 12  election fraud,voter supression,fake electors,...
# 13  foreign policy,ukraine,russia,china,nato,allia...
# 14                         coronavirus,covid,pandemic
# 15                                  avoidingNaNvalues
# 16                       investigation,investigations
# 17                       investigation,investigations
#
#                                         expanded dict
# 0   rights,murder,violation,body,abortion,pro choi...
# 1   books,book,ban,bans,banning,banned,parents,cho...
# 2    immigration,migration,crisis,migrants,assylum...
# 3   drug,drugs,theft,violent,violence,chaos,societ...
# 4                                   avoidingNaNvalues
# 5   guns,mass shooting,mass shootings,second ammen...
# 6   energy policy,green new deal,renewable energy,...
# 7                                   avoidingNaNvalues
# 8   black lives matter,blm,police,misconduct,socia...
# 9                                   avoidingNaNvalues
# 10                                  avoidingNaNvalues
# 11  energy policy,green new deal,renewable energy,...
# 12  election fraud,voter supression,jim crow,janua...
# 13  freedom,democracy,dictator,weapons,nato,allian...
# 14  coronavirus,covid,pandemic,mandates,safety,pro...
# 15                                  avoidingNaNvalues
# 16  january 6,classified documents,taxes,trump,cla...
# 17  laptop,burisma,classified documents,hunter,bid...

# %%
import re

# %%
data2=data #.copy()
#data2['url'][2] = None

# %%
for count, pewrow in enumerate(pew['primary dict']):
    pew['primary dict'][count] = pewrow.split(',')
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_12620\3839292690.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pew['primary dict'][count] = pewrow.split(',')

# %%
for row in pew['primary dict']:
    print(row)
    for word in row:
        print(word)
# Out:
# ['abortion', 'pro choice', 'pro-choice', 'pro life', 'pro-life', 'dobbs']
# abortion
# pro choice
# pro-choice
# pro life
# pro-life
# dobbs
# ['education', 'schools', 'school', 'teachers', 'teacher']
# education
# schools
# school
# teachers
# teacher
# ['immigration', 'migration', 'immigrants', ' migrants', 'assylum', 'southern border']
# immigration
# migration
# immigrants
#  migrants
# assylum
# southern border
# ['crime']
# crime
# ['health care']
# health care
# ['guns', 'mass shooting', 'mass shootings', ' second ammendment', 'assault weapons']
# guns
# mass shooting
# mass shootings
#  second ammendment
# assault weapons
# ['energy policy', 'green new deal', ' renewable energy', 'renewables', 'wind', ' solar', 'electrification', 'fossil fuels']
# energy policy
# green new deal
#  renewable energy
# renewables
# wind
#  solar
# electrification
# fossil fuels
# ['economy', 'inflation', 'jobs', 'wages', 'unemployment', ' salaries']
# economy
# inflation
# jobs
# wages
# unemployment
#  salaries
# ['black lives matter', 'blm', 'police misconduct', 'social justice']
# black lives matter
# blm
# police misconduct
# social justice
# ['supreme court', ' justices']
# supreme court
#  justices
# ['small government', 'big government', 'spending cuts']
# small government
# big government
# spending cuts
# ['climate change', 'global warming']
# climate change
# global warming
# ['election fraud', 'voter supression', 'fake electors', 'january 6', 'january 6th']
# election fraud
# voter supression
# fake electors
# january 6
# january 6th
# ['foreign policy', 'ukraine', 'russia', 'china', 'nato', 'alliance', 'putin', 'xi', 'jinping']
# foreign policy
# ukraine
# russia
# china
# nato
# alliance
# putin
# xi
# jinping
# ['coronavirus', 'covid', 'pandemic']
# coronavirus
# covid
# pandemic
# ['avoidingNaNvalues']
# avoidingNaNvalues
# ['investigation', 'investigations']
# investigation
# investigations
# ['investigation', 'investigations']
# investigation
# investigations

# %%
for row in pew['issue']:
    data2[row] = None

data2
# Out:
#                                                    url  \
# 0    https://www.foxnews.com/opinion/tucker-carlson...
# 1    https://www.foxnews.com/opinion/tucker-carlson...
# 2    https://www.foxnews.com/opinion/tucker-carlson...
# 3    https://www.foxnews.com/opinion/tucker-carlson...
# 4    https://www.foxnews.com/opinion/tucker-carlson...
# ..                                                 ...
# 642  https://www.foxnews.com/opinion/tucker-carlson...
# 643  https://www.foxnews.com/opinion/tucker-carlson...
# 644  https://www.foxnews.com/opinion/tucker-carlson...
# 645  https://www.foxnews.com/opinion/tucker-carlson...
# 646  https://www.foxnews.com/opinion/tucker-carlson...
#
#                           timestamp  \
# 0      February 9, 2023 10:19pm EST
# 1      February 8, 2023 10:25pm EST
# 2      February 7, 2023 10:51pm EST
# 3       February 6, 2023 9:33pm EST
# 4       February 3, 2023 9:59pm EST
# ..                              ...
# 642    November 19, 2019 1:30pm EST
# 643    November 15, 2019 1:09pm EST
# 644    November 14, 2019 9:24am EST
# 645   November 13, 2019 10:13am EST
# 646   November 12, 2019 10:08am EST
#
#                                                  title  \
# 0    TUCKER CARLSON: Self-defense is becoming illeg...
# 1    TUCKER CARLSON: The lies 'just kept coming' du...
# 2    TUCKER CARLSON: America's problems are fixable...
# 3    TUCKER CARLSON: The people who owe you the tru...
# 4    TUCKER CARLSON: Biden administration's stance ...
# ..                                                 ...
# 642  Tucker Carlson: Media, federal government toug...
# 643  Tucker Carlson: Trump impeachment inquiry will...
# 644  Tucker Carlson: It's never been clear what Dem...
# 645  Tucker Carlson: The end of free speech – What ...
# 646  Tucker Carlson: Elizabeth Warren's enemies on ...
#
#                                                   text  \
# 0    warning: graphic footage—fox news host tucker ...
# 1     fox news host tucker carlson reacts to presid...
# 2    fox news host tucker carlson breaks down the t...
# 3    fox news host tucker carlson calls out the bid...
# 4     fox news host tucker carlson takes on the bid...
# ..                                                 ...
# 642  stone found guilty on all seven counts; epstei...
# 643  media goes into overdrive on impeachment heari...
# 644  first public impeachment hearings take place.i...
# 645  liberals working to crack down on the first am...
# 646  warren's campaign backed by the same wealthy d...
#
#                                         text_processed Abortion Education  \
# 0    warning: graphic footage—fox news host tucker ...     None      None
# 1     fox news host tucker carlson reacts to presid...     None      None
# 2    fox news host tucker carlson breaks down the t...     None      None
# 3    fox news host tucker carlson calls out the bid...     None      None
# 4     fox news host tucker carlson takes on the bid...     None      None
# ..                                                 ...      ...       ...
# 642  stone found guilty on all seven counts; epstei...     None      None
# 643  media goes into overdrive on impeachment heari...     None      None
# 644  first public impeachment hearings take placeif...     None      None
# 645  liberals working to crack down on the first am...     None      None
# 646  warren's campaign backed by the same wealthy d...     None      None
#
#     Immigration Violent crime Health care  ...  \
# 0          None          None        None  ...
# 1          None          None        None  ...
# 2          None          None        None  ...
# 3          None          None        None  ...
# 4          None          None        None  ...
# ..          ...           ...         ...  ...
# 642        None          None        None  ...
# 643        None          None        None  ...
# 644        None          None        None  ...
# 645        None          None        None  ...
# 646        None          None        None  ...
#
#     Issues around race and ethnicity Supreme Court appointments  \
# 0                               None                       None
# 1                               None                       None
# 2                               None                       None
# 3                               None                       None
# 4                               None                       None
# ..                               ...                        ...
# 642                             None                       None
# 643                             None                       None
# 644                             None                       None
# 645                             None                       None
# 646                             None                       None
#
#     Size and scope of federal government Climate change Voting policies  \
# 0                                   None           None            None
# 1                                   None           None            None
# 2                                   None           None            None
# 3                                   None           None            None
# 4                                   None           None            None
# ..                                   ...            ...             ...
# 642                                 None           None            None
# 643                                 None           None            None
# 644                                 None           None            None
# 645                                 None           None            None
# 646                                 None           None            None
#
#     Foreign policy The coronavirus outbreak  \
# 0             None                     None
# 1             None                     None
# 2             None                     None
# 3             None                     None
# 4             None                     None
# ..             ...                      ...
# 642           None                     None
# 643           None                     None
# 644           None                     None
# 645           None                     None
# 646           None                     None
#
#     Future of Democracy in the country Investigations into Trump  \
# 0                                 None                      None
# 1                                 None                      None
# 2                                 None                      None
# 3                                 None                      None
# 4                                 None                      None
# ..                                 ...                       ...
# 642                               None                      None
# 643                               None                      None
# 644                               None                      None
# 645                               None                      None
# 646                               None                      None
#
#     Investigations into Biden
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
# ..                        ...
# 642                      None
# 643                      None
# 644                      None
# 645                      None
# 646                      None
#
# [647 rows x 23 columns]

# %%
#Abortion words   
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][0]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Abortion'][count] = match
        
#Education words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][1]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Education'][count] = match       
        
#Immigration words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][2]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Immigration'][count] = match       

#Violent crime words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][3]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Violent crime'][count] = match      
            
#Health care words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][4]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Health care'][count] = match            
#Gun policy words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][5]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Gun policy'][count] = match       
            
#Energy policy words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][6]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Energy policy'][count] = match       
        
#Economy words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][7]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Economy'][count] = match           
                
#Issues around race and ethnicity words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][8]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Issues around race and ethnicity'][count] = match    
            
#Supreme Court appointments words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][9]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Supreme Court appointments'][count] = match   
        
#Size and scope of federal government words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][10]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Size and scope of federal government'][count] = match   
            
#Climate change words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][11]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Climate change'][count] = match   
        
 #Voting policies words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][12]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Voting policies'][count] = match   
        
#Foreign policy words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][13]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Foreign policy'][count] = match   
            
#The coronavirus outbreak words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][14]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['The coronavirus outbreak'][count] = match   

#Future of democracy skip 

#Investigations into Trump words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][16]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Investigations into Trump'][count] = match   
            
#Investigations into Biden words
for count, dfrow in enumerate(data2['text_processed']):
        for word in pew['primary dict'][17]:
            match = re.findall(fr'\b{word}\b',dfrow)
            data2['Investigations into Biden'][count] = match   
        
# for count, dfrow in enumerate(df['text']):
#     for pewrow in pew['primary dict']:
#         print(pewrow)
#         for word in pewrow:
#             print(word)
#             print(count)
#             match = re.findall(fr'\b{word}\b',dfrow)
#             print(match)
#             df['Abortion'][count] = match

# %%
data2=data2.drop(columns = ['url','title','text'])
data2
# Out:
#                           timestamp  \
# 0      February 9, 2023 10:19pm EST
# 1      February 8, 2023 10:25pm EST
# 2      February 7, 2023 10:51pm EST
# 3       February 6, 2023 9:33pm EST
# 4       February 3, 2023 9:59pm EST
# ..                              ...
# 642    November 19, 2019 1:30pm EST
# 643    November 15, 2019 1:09pm EST
# 644    November 14, 2019 9:24am EST
# 645   November 13, 2019 10:13am EST
# 646   November 12, 2019 10:08am EST
#
#                                         text_processed Abortion Education  \
# 0    warning: graphic footage—fox news host tucker ...       []        []
# 1     fox news host tucker carlson reacts to presid...       []        []
# 2    fox news host tucker carlson breaks down the t...       []        []
# 3    fox news host tucker carlson calls out the bid...       []        []
# 4     fox news host tucker carlson takes on the bid...       []        []
# ..                                                 ...      ...       ...
# 642  stone found guilty on all seven counts; epstei...       []        []
# 643  media goes into overdrive on impeachment heari...       []        []
# 644  first public impeachment hearings take placeif...       []        []
# 645  liberals working to crack down on the first am...       []        []
# 646  warren's campaign backed by the same wealthy d...       []        []
#
#            Immigration          Violent crime    Health care Gun policy  \
# 0                   []  [crime, crime, crime]             []         []
# 1                   []                     []             []         []
# 2    [southern border]                     []  [health care]         []
# 3                   []                     []             []         []
# 4                   []                     []             []         []
# ..                 ...                    ...            ...        ...
# 642                 []                [crime]             []         []
# 643                 []                     []             []         []
# 644                 []                [crime]             []         []
# 645                 []                     []             []         []
# 646                 []                     []             []         []
#
#     Energy policy Economy Issues around race and ethnicity  \
# 0              []      []                 [social justice]
# 1              []      []                               []
# 2              []      []                               []
# 3              []      []                               []
# 4              []      []                               []
# ..            ...     ...                              ...
# 642            []      []                               []
# 643            []      []                               []
# 644            []      []                               []
# 645            []      []                               []
# 646            []      []                               []
#
#     Supreme Court appointments Size and scope of federal government  \
# 0                           []                                   []
# 1                           []                                   []
# 2                           []                                   []
# 3                           []                                   []
# 4                           []                                   []
# ..                         ...                                  ...
# 642                         []                                   []
# 643                         []                                   []
# 644                         []                                   []
# 645                         []                                   []
# 646                         []                                   []
#
#     Climate change Voting policies Foreign policy The coronavirus outbreak  \
# 0               []              []             []                       []
# 1               []              []      [jinping]                       []
# 2               []              []             []               [pandemic]
# 3               []              []             []                       []
# 4               []              []             []                       []
# ..             ...             ...            ...                      ...
# 642             []              []             []                       []
# 643             []              []             []                       []
# 644             []              []             []                       []
# 645             []              []             []                       []
# 646             []              []             []                       []
#
#     Future of Democracy in the country Investigations into Trump  \
# 0                                 None                        []
# 1                                 None                        []
# 2                                 None                        []
# 3                                 None                        []
# 4                                 None                        []
# ..                                 ...                       ...
# 642                               None                        []
# 643                               None                        []
# 644                               None                        []
# 645                               None                        []
# 646                               None                        []
#
#     Investigations into Biden
# 0                          []
# 1                          []
# 2                          []
# 3                          []
# 4                          []
# ..                        ...
# 642                        []
# 643                        []
# 644                        []
# 645                        []
# 646                        []
#
# [647 rows x 20 columns]
